# %% [markdown]
# # Combine/Merge All The Data from (https://zenodo.org/records/14227098)

# %% [markdown]
# ## Merge per Month Data into One CSV

# %%
from src.utils.data_loader import load_or_merge_csvs

df = load_or_merge_csvs("../data/raw", "../data/raw/merged_tweets.csv")
df.head()
# Out:
# Loading merged dataset from ../data/raw/merged_tweets.csv
#                         date  \
# 0  2022-04-29 23:59:28+00:00
# 1  2022-04-29 23:58:50+00:00
# 2  2022-04-29 23:58:28+00:00
# 3  2022-04-29 23:58:22+00:00
# 4  2022-04-29 23:57:56+00:00
#
#                                              content lang  month  weekofyear  \
# 0  @KunstJonas "Singing lullabies like 'Twinkle T...   en    NaN         NaN
# 1  Useful, but one of the problems with Long COVI...   en    NaN         NaN
# 2  @AnneMaine3 @Reactively @freemarketrules @Dail...   en    NaN         NaN
# 3  @NSWHealth Dr Moy ( VP AMA)- C19 not done with...   en    NaN         NaN
# 4  @MandateMasksNY @GovKathyHochul @DrMaryTBasset...   en    NaN         NaN
#
#    quarter
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# ## Filter Out other Language and Save it

# %%
df_en = df[df['lang'] == 'en']

df_en.to_csv("../data/raw/merged_tweets_en.csv", index=False)

df_en.head()
# Out:
#                         date  \
# 0  2022-04-29 23:59:28+00:00
# 1  2022-04-29 23:58:50+00:00
# 2  2022-04-29 23:58:28+00:00
# 3  2022-04-29 23:58:22+00:00
# 4  2022-04-29 23:57:56+00:00
#
#                                              content lang  month  weekofyear  \
# 0  @KunstJonas "Singing lullabies like 'Twinkle T...   en    NaN         NaN
# 1  Useful, but one of the problems with Long COVI...   en    NaN         NaN
# 2  @AnneMaine3 @Reactively @freemarketrules @Dail...   en    NaN         NaN
# 3  @NSWHealth Dr Moy ( VP AMA)- C19 not done with...   en    NaN         NaN
# 4  @MandateMasksNY @GovKathyHochul @DrMaryTBasset...   en    NaN         NaN
#
#    quarter
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
